# %% [markdown]
# # <font color="blue"> Lab - 02 <font>

# %% [markdown]
# ### <font color="blue">   Problem (1) Information Extraction using Regular Expression <font>
#
# (1.1) Create and print a list of three to four employees containing the information in the following format:
#
#     Employee Name: Email address: Telephone Number
#
# (1.2) Use regular expressions in Python to extract information from the above list and display in the following format:
#
#     Employee Name:  Email address: Employee Department
#
# (1.3) Use regular expressions in Python to extract the name and telephone information from the list and display in the following format:
#
#     Employee Name: Telephone Number without country code
#
# <font color="blue"> Hint: You can see some code examples about using regular expressions in Python.<font>
# https://regexone.com/references/python

# %%
# import libraries

# %%
#1.1
employee_record = ... # Create list of employee records (name, email, phone)

# Iterate through the list to show records one by one

# Print each iteration

# %%
#1.2
my_pattern = ... # Regex pattern here (format: r'pattern')
#\w is short hand for [a-zA-Z_]
#\d is short hand for [0-9]

# Iterate through employee_record searching for my_pattern, and print

# %%
#1.3
new_pattern = ... # Name and tel. number. 
# For tel. you can select last 8-10 digit after prefix
# Or exclude the first 2 digits, and select all digits after. 

# Iterate through employee_record searching for new_pattern, and print

# %% [markdown]
# ### <font color="blue"> Problem (2) Tokenization
#
#  (2.1) Create a sample document consisting of 4-5 sentences.
#
#  (2.2) Split the sample document into sentences and word tokens and print them.
#
#  (2.3) Use Prettytable to print them in nice tabular format.
#
#  (2.4) Do the sentences and word tokenization using NLTK, print them in pretty table format.Compare both the results.
#
#  (2.5) Compare both the results of NLTK and Textblob tokenization.

# %%
#2.1 

sample_doc = ... # any text will do here

# %%
#2.2
# import text blob modules

# %%
my_text = ... #instantiate TextBlob with your sample_doc

s_token = ... #tokenize by sentences

w_token = ... #tokenize by words

# %%
#2.3 
# import pretty table module

# %%
#Sentence table: 
sen_table = ... 

# iterate through sentence tokens, and append to table 

#Word table: 
word_table = ...

#iterate through word tokens, and append to table

# %%
#2.4 
#import tokenizers from nltk

# %%
#create new pretty tables for word and sentence tokens


# iterate through word and sentence tokens and append to both pretty tables

# %% [markdown]
# ### Problem (3) Stemming and Lemmatization
#
# and try the both NLTK and spacy to see which one performs better.
#
# (3.0) Create and print a sample text (you can also use the quotes from: (https://www.brainyquote.com/topics/famous)
#
# (3.1) Stem the words of a sample text by using the nltk package. Print them in the following format:
#     [Word] [Word Stem]
#
# (3.2) Lemmatize the words of a sample text by using the nltk package. Print them in the following format:
#     [Word] [Word Lemma in NLTK]
#
# (3.3) Lemmatize the words of a sample text by using the spacy package. Print them in the following format:
#     [Word] [Word Lemma in spaCy]
#
# (3.4) compare both the  Lemmatization results.

# %%
#Import stemming and lematization modules from nltk

# %%
text = ... #your text here

# %%
#3.1 
#tokenize your text

# %%
# iterate through your stemmed tokens

# create pretty table for stemed words (word : word stem)

# %%
#3.2 
# iterate over your lemmatized tokens

# create pretty table for lemmas (word : word lemma i)

# %%
#3.3
# import spacy modules

# %%
doc = ... # use the spacy pipeline on your text

# iterate over your lemmatized tokens

#format in a pretty table

# %% [markdown]
# ### Problem (5) Named Entity Recognition
#
#  (5.0) Create a sample text document (Ex: you can use email about an event or a conference invitation).
#
#  (5.1) Define a function to do the Entity recontion by using NLTK library and print them as: [Entity | Label]
#
#  (5.2) Do the same by using spaCy library. Visualize the results using displacy.
#
#  (5.3) Compare both the results of NLTK and spaCy.
#
#    <font color="brown"> Hint: You can look into this blog for more information. https://towardsdatascience.com/named-entity-recognition-with-nltk-and-spacy-8c4a7d88e7da <font>

# %%
# 5.0 
sample_text = ...

# %%
sentences = ... #tokenize your sample text

ner_nltk_table = ... #instantiate the table

# %%
# 5.1 Named Entity Recognition with NLTK

def NER_nltk(): 
    #iterate through the sentences
    
    # tokenize the words within each sentence
    
    # create POS tags for each token
    
    # extract named entities
    
    
    # present the results in your ner_nltk_table
        
    
    print(ner_nltk_table)

# %%
# test your function 
NER_nltk()

# %%
#5.2 NER with spaCy
#import and instantiate spaCy english language module:

# %%
ner_spacy_table = ...

# %%
# function takes a doc (string) and prints NER table with all 
# identified entities from the doc

def NER_spacy(doc): 
    # identify entities in your doc 
    entities = 
    
    # for each token in the recognized entities
    
    # add a row (in format: 'entity', 'label') to your table

# %%
# run spacy language module on sample_text:
my_doc = ...

# %%
# test your function
NER_spacy( my_doc)

# %%
# Tip: try visualizing the resutls of the entity recognizer with displaCy
