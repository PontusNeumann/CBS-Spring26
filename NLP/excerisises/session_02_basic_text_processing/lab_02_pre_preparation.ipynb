# %% [markdown]
# # <font color="blue"> Tasks to do before the exercise Session <font>

# %% [markdown]
# ### <font color="blue">  Task 1 Install the following packages    <font>
#     (You can use pip to install these packages)
#
# (1.1) Natural Language Toolkit (NLTK) along with NLTK Data (https://www.nltk.org/)
#
# (1.2) TextBlob: Simplified Text Processing (https://textblob.readthedocs.io/en/dev/)
#
# (1.3) spaCy Industrial-Strength Natural Language Processing in Python (https://spacy.io/)
#
# (1.4) Prettytable Package for showing the results in pretty tabular format.
#
# <font color="brown"> NOTE 1<font> First install NLTK, before installing TextBlob, as TextBlob internally uses NLTK.
#
# <font color="brown"> NOTE 2<font> If you get problems in loading spacy, to fix an error: spacy.load('en_core_web_sm') error, use the following command.
#
# pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.0.0/en_core_web_sm-2.0.0.tar.gz#egg=en_core_web_sm

# %%
# (3) you can install packages in jupyter notebook by using ! in front of pip:

#!pip install nltk
#!pip install -U textblob
#!pip install prettytable
#!pip install spacy

# %% [markdown]
# ### <font color="blue"> Task 2 Regular Expressions Tutorial  <font>
#
# Go to: https://regexone.com/lesson/introduction_abcs and familiarise your self with the regular expression syntax. Complete all the 15 tutorials without looking into solution. If you get stuck and even after discussing with others, if you dont get answer, then you may look into the solution.

# %% [markdown]
# ### <font color="blue"> Task 3  Make yourself familier with the following POS tag list <font>

# %%
# POS tag list:

# CC	coordinating conjunction
# CD	cardinal digit
# DT	determiner
# EX	existential there (like: "there is" ... think of it like "there exists")
# FW	foreign word
# IN	preposition/subordinating conjunction
# JJ	adjective	'big'
# JJR	adjective, comparative	'bigger'
# JJS	adjective, superlative	'biggest'
# LS	list marker	1)
# MD	modal	could, will
# NN	noun, singular 'desk'
# NNS	noun plural	'desks'
# NNP	proper noun, singular	'Harrison'
# NNPS	proper noun, plural	'Americans'
# PDT	predeterminer	'all the kids'
# POS	possessive ending	parent\'s
# PRP	personal pronoun	I, he, she
# PRP$	possessive pronoun	my, his, hers
# RB	adverb	very, silently,
# RBR	adverb, comparative	better
# RBS	adverb, superlative	best
# RP	particle	give up
# TO	to	go 'to' the store.
# UH	interjection	errrrrrrrm
# VB	verb, base form	take
# VBD	verb, past tense	took
# VBG	verb, gerund/present participle	taking
# VBN	verb, past participle	taken
# VBP	verb, sing. present, non-3d	take
# VBZ	verb, 3rd person sing. present	takes
# WDT	wh-determiner	which
# WP	wh-pronoun	who, what
# WP$	possessive wh-pronoun	whose
# WRB	wh-abverb	where, when
