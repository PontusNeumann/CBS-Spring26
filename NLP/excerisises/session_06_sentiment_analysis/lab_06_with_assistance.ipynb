# %% [markdown]
# # <font color='white'> Lab-06 <font>

# %% [markdown]
# ### <font color='white'> Data Preparation <font>
#
# Download Emotios dataset from Kaggle https://www.kaggle.com/datasets/nelgiriyewithana/emotions
#
# Use Pandas to load the dataset and display the first fifteen rows of the dataset.

# %%
# (0.1)
import pandas as pd
df = ...
df.head(10)

# %%
# alternitively, you can try to use Kaggle's API (you don't have to do both ofc)
# %pip install kagglehub
import kagglehub
import pandas as pd

# Download latest version
path = kagglehub.dataset_download("nelgiriyewithana/emotions")

print("Path to dataset files:", path)

df = pd.read_csv(path) #remember adding the csv file
df.head(10)

# %% [markdown]
# ### <font color='white'> Problem 1: Data Pre-processing <font>
#
#
# (1.1) Write a function, `data_preprocess`, to **tokenize** text, remove **stopwords** and non-alphabetic tokens, apply **lemmatization**, and rejoin tokens into a **single string**.
#
# (1.2) Load the dataset and apply the data_preprocess function to pre-process the text data. Preview the data to ensure pre-processing is as expected.

# %%
# (1.1)

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# Download the required NLTK data
nltk.download('punkt')          # downloads the punkt tokenizer models, which are used for sentence and word tokenization: fx. "word_tokenize()" or "sent_tokenize()$"
nltk.download('stopwords')      # downloads the stopwords corpus
nltk.download('wordnet')        # downloads the WordNet lexical database, which is necessary for lemmatization: fx. WordNetLemmatizer()

# Initialize the lemmatizer and english stopwords list
stop_words = ...
lem = ...

# Create the data preprocessing function
def data_preprocess(text):
    # Tokenize text
    wtokens = ...

   # Filtering tokens
    t_filtered = []
    for t in wtokens:
        # Convert token to lowercase and check if it's not in stopwords and is alphabetic (use the isalpha() method)
        if ... not in ... and ...:
        # Add the lowercase token to filtered_tokens
        ...

   # Lemmatization
    t_lemmatized = []
    for t in t_filtered:
    # Lemmatize token
        lemma_t = ...
    # Add lemmatized token to lemmatized_tokens
        ...

    # Rejoin the processed tokens into a single string
    return " ".join(t_lemmatized) #h ere we use a space (" ") as the separator

# (1.2) Apply your preprocessing function to the 'text' column and store it
    # this might take 1 minute or more

# %% [markdown]
# ### <font color='white'> Problem 2:  Sentiment analysis with TextBlob <font>
#
# Use TextBlob to perform **sentiment analysis** on a sample of texts from the dataset.
#
# Calculate the sentiment _polarity_ and _subjectivity_ of random 5 texts from the dataset and determine if each text is positive, negative, or neutral based on the polarity score.

# %%
#Select a sample of 5 examples of your preprocessed text from Problem 1
    # for this, use "sample(number)"
random_text = ...

from textblob import TextBlob

#Create a loop to conduct sentiment analysis
for i, text in enumerate(random_text,start=1):
    #initialize TextBlob object
    tb = ...
    #get sentiment polarity:
    score = tb...
    #get sentiment subjectivity:
    subj = tb...
    #print the results
    print(f"({i}) {text}\nSentiment polarity: {round(score,2)}\nSentiment subjectivity: {round(subj,2)}\n")

# %% [markdown]
# ### <font color='white'> Problem 3:  Sentiment analysis with VADER <font>
#
# Analyze the sentiment of same 5 random texts using VADER.
#
# Discuss how VADER’s scores (positive, negative, neutral, compound) provide a nuanced view of sentiment.

# %%
# %pip install VADER #if needed

# We download the required nltk resources
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

#initialize the VADER sentiment analyzer
vdr = ...

#Create a loop to conduct sentiment analysis using your random_text from Problem 2
for i, text in enumerate(random_text,start=1):
    # get the polarity scores
    vsa = vdr...
    #Print your results:
    print(f"({i}) {text}\nVADER Scores: {vsa}\n")

# %% [markdown]
# ### <font color='white'> Problem 4:  Sentiment analysis Using AFINN <font>
#
# (4.1) Install the `afinn` module.
#
# (4.2) Use the AFINN library to calculate sentiment scores for the same 5 random texts.
#
# (4.3) Compare the scores against those obtained from TextBlob and VADER.

# %%
# (3.1)
# !pip install afinn

# (3.2)
from afinn import Afinn
#initialize the AFINN sentiment analyzer
afinn = ...

# Create a loop to conduct sentiment analysis using your random_text from Problem 2
for i,text in enumerate(random_text,start=1):
    # get the AFINN score
    score = ...
    #print your results
    print(f"({i}) {text}\nAFINN Score: {score}\n")

# %% [markdown]
# ### <font color='white'> Problem 5:  Build a Simple Classifier for Sentiment Analysis with scikit-learn <font>
#
# (5.1) Preprocess the dataset to create a binary sentiment label (positive or negative) based on TextBlob’s sentiment polarity.
#
# (5.2) Split the dataset into training and testing sets.
#
# (5.3) Convert the text data into numeric data by using TF-IDF.
#
# (5.4) Train a Logistic Regression model and evaluate its performance on the test set. Print the classification report.

# %%
# import necessary ressources
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report


# (5.1) Creating a binary sentiment label based on TextBlob's sentiment polarity
df['sentiment_label'] = df['text'].apply(lambda x: 'positive' if ... else 'negative')

# (5.2)
X_train, X_test, y_train, y_test = train_test_split(...)

#(5.3)
#Initialize the TfidfVectorizer
num = ...
#Fit and transform the training data
X_train_tfidf = ...
# (only)Transform the test data
X_test_tfidf = ...

#(5.4)
#Initialize the Logistic Regression model
lrm = ...
#Fit the model
lrm...
#Compute the predictions of the model
y_predicted = lrm...

#Print the classification report:
print(classification_report(...))

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report


# (5.1) Creating a binary sentiment label based on TextBlob's sentiment polarity
df['sentiment_label'] = df['text'].apply(lambda x: 'positive' if ... else 'negative')

# (5.2)
X_train, X_test, y_train, y_test = train_test_split(...)

#(5.3)
#Initialize the TfidfVectorizer
num = TfidfVectorizer()
#Fit and transform the training data
X_train_tfidf = ...
# Transform the test data
X_test_tfidf = ...

#(5.4)
#Initialize the Logistic Regression model
lrm = ...
#Fit the model
lrm...
#Compute the predictions of the model
y_predicted = lrm...

#Print the classification report:
print(classification_report(...))

# %% [markdown]
# ### <font color='white'> Bonus Problem (Optional): Sentiment Analysis using SentiWordNet <font>
#
# Use SentiWordNet to calculate sentiment scores for each text entry.
#
# Assign a sentiment category based on the scores.
#
# Display the first 15 entries to see the sentiment scores.

# %%
import nltk
from nltk.corpus import sentiwordnet as swn, wordnet
from nltk import pos_tag

# Download
nltk.download('averaged_perceptron_tagger') # For part-of-speech tagging
nltk.download('sentiwordnet') #For accessing SentiWordNet

def get_wordnet_pos(treebank_tag):
    """Converts part-of-speech tags from the Penn Treebank tag to a WordNet tag."""
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        # As default case, return NOUN
        return wordnet.NOUN

def sentiment_analysis(text):
    """Performs sentiment analysis using SentiWordNet."""
    # Preprocess the text and obtain lemmatized tokens using your preprocessing fucntion from above
    # Make sure to use word_tokenize as data_preprocess() returns the joined string and you need the tokens
    mytokens = ...

# POS tagging on the lemmatized tokens
    pos_tagging = ...

    pos_score = 0
    neg_score = 0

    # For each word and tag in pos_tagging, get the sentiment score
    for w, t in pos_tagging:
        wn_tag = ...
        synsets = ...

        # If there are no synsets, skip the word
        if not synsets:
            continue

        # Take the first synset
        synset = synsets[0]
        #Compite the positive and negative scores
        pos_score += ...
        neg_score += ...

    # Compute the overall score by subtracting the negative score from the positive score
    score = ...
    return score

#Apply the sentiment_analysis function to the 'text' column and store it in a new column
df['sentiment_score'] = ...

# Display the first 15 entries to see the sentiment scores
df...
