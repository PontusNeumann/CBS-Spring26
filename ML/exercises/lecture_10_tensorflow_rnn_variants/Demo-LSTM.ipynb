# %% [markdown]
# ## Demo: PREDICTING BITCOIN PRICE USING LSTM MODEL

# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in /opt/conda/lib/python3.12/site-packages (from scikit-learn) (2.4.2)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.17.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 22.0 MB/s  0:00:00 eta 0:00:01
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading scipy-1.17.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.2/35.2 MB 45.6 MB/s  0:00:00m0:00:0100:01
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [scikit-learn] [scikit-learn]
# Successfully installed joblib-1.5.3 scikit-learn-1.8.0 scipy-1.17.1 threadpoolctl-3.6.0

# %%
# Import packages
# Author Saad
import time
import math
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import datetime as datetime
import plotly.express as px



import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import activations


from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from tensorflow.keras import optimizers
from sklearn import preprocessing
from joblib import dump, load

np.random.seed(7)

# %%
# READ DATA FROM FILE
df = pd.read_csv("bitcoin_hourly.csv")
print(df.dtypes)
print("\n*** DF ***")
df_copy = df.copy()
df_copy.head(5)
# Out:
# unix           float64
# date            object
# symbol          object
# open           float64
# high           float64
# low            float64
# close          float64
# Volume BTC     float64
# Volume USDT    float64
# tradecount     float64
# dtype: object
#
# *** DF ***
#            unix                 date    symbol      open      high       low  \
# 0  1.614384e+12  2021-02-27 00:00:00  BTC/USDT  46276.88  46628.93  46156.24
# 1  1.614380e+12  2021-02-26 23:00:00  BTC/USDT  45476.30  46444.57  45368.74
# 2  1.614377e+12  2021-02-26 22:00:00  BTC/USDT  45680.00  45988.77  45000.00
# 3  1.614373e+12  2021-02-26 21:00:00  BTC/USDT  46270.00  46867.00  45500.00
# 4  1.614370e+12  2021-02-26 20:00:00  BTC/USDT  46959.18  47115.38  46071.89
#
#       close   Volume BTC   Volume USDT  tradecount
# 0  46621.39   336.166565  1.558817e+07      8582.0
# 1  46276.87  2571.865785  1.185428e+08     60317.0
# 2  45476.30  4400.975291  2.005474e+08    123927.0
# 3  45677.46  3831.690182  1.771737e+08     85141.0
# 4  46270.00  3514.297867  1.637276e+08     80837.0

# %%
#CLEAN DATA - SPECIFICALLY CLEAN TIMESTAMP

def change_timestamp (ts):
    digit_count = len(str(ts))
    if digit_count == 12:
        return (datetime.datetime.utcfromtimestamp(ts)).strftime('%Y-%m-%d %H:%M:%S')
    else:
        return (datetime.datetime.utcfromtimestamp(ts/1000)).strftime('%Y-%m-%d %H:%M:%S')

df_copy['unix_count'] = df.unix.apply(lambda x: len(str(x)))        
df_copy['dt_correct'] = df.unix.apply(lambda x: change_timestamp(x))
df_copy['dt'] = pd.to_datetime(df_copy.dt_correct.values)
df_copy['hour'] = df_copy.dt.apply(lambda x: x.hour)
df_copy['week_day'] = df_copy.dt.apply(lambda x: x.weekday())
df_copy.sort_values(by=['unix'],ascending=[True],inplace=True)

print(df_copy.dtypes)
print(df_copy.unix_count.unique())
df_copy.tail(5)
# Out:
# /tmp/ipykernel_1962/4197614359.py:8: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   return (datetime.datetime.utcfromtimestamp(ts/1000)).strftime('%Y-%m-%d %H:%M:%S')
# /tmp/ipykernel_1962/4197614359.py:6: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   return (datetime.datetime.utcfromtimestamp(ts)).strftime('%Y-%m-%d %H:%M:%S')
# unix                  float64
# date                   object
# symbol                 object
# open                  float64
# high                  float64
# low                   float64
# close                 float64
# Volume BTC            float64
# Volume USDT           float64
# tradecount            float64
# unix_count              int64
# dt_correct             object
# dt             datetime64[ns]
# hour                    int64
# week_day                int64
# dtype: object
# [12 15]
#            unix                 date    symbol      open      high       low  \
# 4  1.614370e+12  2021-02-26 20:00:00  BTC/USDT  46959.18  47115.38  46071.89
# 3  1.614373e+12  2021-02-26 21:00:00  BTC/USDT  46270.00  46867.00  45500.00
# 2  1.614377e+12  2021-02-26 22:00:00  BTC/USDT  45680.00  45988.77  45000.00
# 1  1.614380e+12  2021-02-26 23:00:00  BTC/USDT  45476.30  46444.57  45368.74
# 0  1.614384e+12  2021-02-27 00:00:00  BTC/USDT  46276.88  46628.93  46156.24
#
#       close   Volume BTC   Volume USDT  tradecount  unix_count  \
# 4  46270.00  3514.297867  1.637276e+08     80837.0          15
# 3  45677.46  3831.690182  1.771737e+08     85141.0          15
# 2  45476.30  4400.975291  2.005474e+08    123927.0          15
# 1  46276.87  2571.865785  1.185428e+08     60317.0          15
# 0  46621.39   336.166565  1.558817e+07      8582.0          15
#
#             dt_correct                  dt  hour  week_day
# 4  2021-02-26 20:00:00 2021-02-26 20:00:00    20         4
# 3  2021-02-26 21:00:00 2021-02-26 21:00:00    21         4
# 2  2021-02-26 22:00:00 2021-02-26 22:00:00    22         4
# 1  2021-02-26 23:00:00 2021-02-26 23:00:00    23         4
# 0  2021-02-27 00:00:00 2021-02-27 00:00:00     0         5

# %%
df_work = df_copy[['dt','hour','week_day','close','Volume BTC']]

# %%
#SPLIT DATA INTO TEST AND TRAIN
np.random.seed(7)

X = df_work[['hour','week_day','Volume BTC','close']]
Y = df_work[['close']]


#NORMALIZATION
f_transformer = preprocessing.MinMaxScaler((-1,1))
f_transformer = f_transformer.fit(X)

cnt_transformer = preprocessing.MinMaxScaler((-1,1))
cnt_transformer = cnt_transformer.fit(Y)

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, shuffle = False)

X_train_trans = f_transformer.transform(X_train)
X_test_trans = f_transformer.transform(X_test)

y_train_trans = cnt_transformer.transform(y_train)
y_test_trans = cnt_transformer.transform(y_test)

print("*** SHAPES")
print("X_train: %s, %s" % (X_train.shape[0],X_train.shape[1]))
print("X_test: %s, %s" % (X_test.shape[0],X_test.shape[1]))
print("y_train: %s, %s" % (y_train.shape[0],y_train.shape[1]))
print("y_test: %s, %s" % (y_test.shape[0],y_test.shape[1]))

print("\n*** MIN MAX")

print("TRAIN COST: %d, %d" % (X_train.close.min(), X_train.close.max()))
print("TEST COST: %d, %d" % (X_test.close.min(), X_test.close.max()))
print("TRAIN VOL: %d, %d" % (X_train['Volume BTC'].min(), X_train['Volume BTC'].max()))
print("TEST VOL: %d, %d" % (X_test['Volume BTC'].min(), X_test['Volume BTC'].max()))

print("\n*** MIN MAX PARAMETER")
print(f_transformer.data_min_)
print(f_transformer.data_max_)
print(cnt_transformer.data_min_)
print(cnt_transformer.data_max_)
# Out:
# *** SHAPES
# X_train: 26876, 4
# X_test: 6720, 4
# y_train: 26876, 1
# y_test: 6720, 1
#
# *** MIN MAX
# TRAIN COST: 2919, 19709
# TEST COST: 9946, 58183
# TRAIN VOL: 0, 47255
# TEST VOL: 0, 32057
#
# *** MIN MAX PARAMETER
# [   0.    0.    0. 2919.]
# [2.300000e+01 6.000000e+00 4.725576e+04 5.818369e+04]
# [2919.]
# [58183.69]

# %%
#CREATE LAGGING DATASET FOR TIMESERIES
def create_dataset(X, y, time_steps=1):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        v = X[i:(i + time_steps)]
        Xs.append(v)
        ys.append(y[i + time_steps])
    return np.array(Xs), np.array(ys)

time_steps = 24
# reshape to [samples, time_steps, n_features]
X_train_f, y_train_f = create_dataset(X_train_trans, y_train_trans, time_steps)
X_test_f, y_test_f = create_dataset(X_test_trans, y_test_trans, time_steps)

print("*** SHAPES")
print(X_train_f.shape, y_train_f.shape)
print(X_test_f.shape, y_test_f.shape)
# Out:
# *** SHAPES
# (26852, 24, 4) (26852, 1)
# (6696, 24, 4) (6696, 1)

# %%
# Building the model
model = keras.Sequential()
model.add(keras.Input(shape=((X_train_f.shape[1], X_train_f.shape[2]))))

model.add(layers.LSTM(300, return_sequences=False, activation = 'tanh'))
model.add(layers.BatchNormalization())

model.add(keras.layers.Dense(units=1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 300)            │       366,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 300)            │         1,200 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           301 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 367,501 (1.40 MB)
#  Trainable params: 366,901 (1.40 MB)
#  Non-trainable params: 600 (2.34 KB)

# %%
hist = model.fit(X_train_f, y_train_f, batch_size = 200, epochs = 50, shuffle=False, validation_split=0.1)
# Out:
# Epoch 1/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 67s 537ms/step - loss: 0.2113 - val_loss: 0.0072
# Epoch 2/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 62s 510ms/step - loss: 0.0130 - val_loss: 0.0075
# Epoch 3/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 56s 461ms/step - loss: 0.0135 - val_loss: 0.0063
# Epoch 4/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 57s 469ms/step - loss: 0.0135 - val_loss: 0.0065
# Epoch 5/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 56s 462ms/step - loss: 0.0133 - val_loss: 0.0042
# Epoch 6/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 55s 458ms/step - loss: 0.0132 - val_loss: 0.0020
# Epoch 7/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 55s 457ms/step - loss: 0.0131 - val_loss: 9.0984e-04
# Epoch 8/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 55s 453ms/step - loss: 0.0136 - val_loss: 0.0017
# Epoch 9/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 56s 465ms/step - loss: 0.0155 - val_loss: 0.0030
# Epoch 10/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 56s 466ms/step - loss: 0.0129 - val_loss: 8.3523e-04
# Epoch 11/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 56s 462ms/step - loss: 0.0129 - val_loss: 3.1312e-04
# Epoch 12/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 56s 459ms/step - loss: 0.0130 - val_loss: 3.5842e-04
# Epoch 13/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 56s 461ms/step - loss: 0.0129 - val_loss: 0.0064
# Epoch 14/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 56s 462ms/step - loss: 0.0131 - val_loss: 0.0012
# Epoch 15/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 55s 457ms/step - loss: 0.0132 - val_loss: 5.1771e-04
# Epoch 16/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 56s 461ms/step - loss: 0.0159 - val_loss: 0.0107
# Epoch 17/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 56s 463ms/step - loss: 0.0139 - val_loss: 0.0449
# Epoch 18/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 56s 461ms/step - loss: 0.0130 - val_loss: 0.0100
# Epoch 19/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 64s 533ms/step - loss: 0.0129 - val_loss: 0.0024
# Epoch 20/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 64s 527ms/step - loss: 0.0130 - val_loss: 1.2812e-04
# Epoch 21/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 64s 531ms/step - loss: 0.0130 - val_loss: 4.4940e-04
# Epoch 22/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 64s 525ms/step - loss: 0.0131 - val_loss: 3.8220e-04
# Epoch 23/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 62s 514ms/step - loss: 0.0130 - val_loss: 1.7678e-04
# Epoch 24/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 62s 508ms/step - loss: 0.0130 - val_loss: 1.8525e-04
# Epoch 25/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 61s 503ms/step - loss: 0.0131 - val_loss: 0.0036
# Epoch 26/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 60s 497ms/step - loss: 0.0164 - val_loss: 0.0110
# Epoch 27/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 62s 511ms/step - loss: 0.0133 - val_loss: 1.4204e-04
# Epoch 28/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 64s 526ms/step - loss: 0.0132 - val_loss: 0.0013
# Epoch 29/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 64s 531ms/step - loss: 0.0132 - val_loss: 0.0021
# Epoch 30/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 64s 527ms/step - loss: 0.0132 - val_loss: 0.0021
# Epoch 31/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 64s 525ms/step - loss: 0.0132 - val_loss: 0.0039
# Epoch 32/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 64s 530ms/step - loss: 0.0133 - val_loss: 0.0040
# Epoch 33/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 63s 520ms/step - loss: 0.0140 - val_loss: 4.5683e-04
# Epoch 34/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 63s 522ms/step - loss: 0.0138 - val_loss: 0.0572
# Epoch 35/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 63s 518ms/step - loss: 0.0134 - val_loss: 0.0018
# Epoch 36/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 63s 523ms/step - loss: 0.0133 - val_loss: 0.0018
# Epoch 37/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 62s 516ms/step - loss: 0.0133 - val_loss: 1.4961e-04
# Epoch 38/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 62s 515ms/step - loss: 0.0133 - val_loss: 4.5905e-04
# Epoch 39/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 62s 516ms/step - loss: 0.0133 - val_loss: 3.2668e-04
# Epoch 40/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 63s 524ms/step - loss: 0.0133 - val_loss: 3.2565e-04
# Epoch 41/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 63s 518ms/step - loss: 0.0133 - val_loss: 8.4122e-04
# Epoch 42/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 62s 515ms/step - loss: 0.0143 - val_loss: 1.3599e-04
# Epoch 43/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 63s 519ms/step - loss: 0.0134 - val_loss: 0.0010
# Epoch 44/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 63s 519ms/step - loss: 0.0134 - val_loss: 0.0037
# Epoch 45/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 63s 519ms/step - loss: 0.0138 - val_loss: 0.0088
# Epoch 46/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 62s 514ms/step - loss: 0.0138 - val_loss: 0.0055
# Epoch 47/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 63s 518ms/step - loss: 0.0134 - val_loss: 9.9634e-04
# Epoch 48/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 64s 526ms/step - loss: 0.0133 - val_loss: 5.9668e-04
# Epoch 49/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 63s 518ms/step - loss: 0.0134 - val_loss: 0.0049
# Epoch 50/50
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 63s 524ms/step - loss: 0.0134 - val_loss: 0.0057

# %%
loss = hist.history['loss']
val_loss = hist.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
y_pred = model.predict(X_test_f) 

y_test_inv = cnt_transformer.inverse_transform(y_test_f)
y_pred_inv = cnt_transformer.inverse_transform(y_pred)
combined_array = np.concatenate((y_test_inv,y_pred_inv),axis=1)
combined_array2 = np.concatenate((X_test.iloc[time_steps:],combined_array),axis=1)

df_final = pd.DataFrame(data = combined_array, columns=["actual", "predicted"])
print("size: %d" % (len(combined_array)))
df_final.head(4)
# Out:
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step
# size: 6696
#      actual     predicted
# 0  10223.57  12320.765625
# 1  10284.47  12325.491211
# 2  10259.81  12369.798828
# 3  10260.75  12375.893555

# %%
results = model.evaluate(X_test_f, y_test_f)

print("mse: %s" % (mean_squared_error(y_test_inv, y_pred_inv)))
print(results)
# Out:
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0161
# mse: 12294782.409886293
# 0.016102204099297523

# %%
##PREPARING DATA FOR PLOTLY

a = np.repeat(1, len(y_test_inv))
b = np.repeat(2, len(y_pred_inv))

df1 = pd.DataFrame(data = np.concatenate((y_test_inv,(np.reshape(a, (-1, 1)))),axis=1), columns=["price","type"])
df2 = pd.DataFrame(data = np.concatenate((y_pred_inv,(np.reshape(b, (-1, 1)))),axis=1), columns=["price","type"])

frames = [df1, df2]
result = pd.concat(frames, ignore_index=False)

result["type"].replace({1: "actual", 2: "predict"}, inplace=True)
(result[result.type == "actual"]).head(10)
# Out:
# /tmp/ipykernel_1962/1179579725.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   result["type"].replace({1: "actual", 2: "predict"}, inplace=True)
#       price    type
# 0  10223.57  actual
# 1  10284.47  actual
# 2  10259.81  actual
# 3  10260.75  actual
# 4  10293.61  actual
# 5  10319.05  actual
# 6  10285.47  actual
# 7  10252.60  actual
# 8  10289.42  actual
# 9  10262.41  actual

# %%
(result[result.type == "predict"]).head(10)
# Out:
#           price     type
# 0  12320.765625  predict
# 1  12325.491211  predict
# 2  12369.798828  predict
# 3  12375.893555  predict
# 4  12382.560547  predict
# 5  12426.889648  predict
# 6  12450.166992  predict
# 7  12432.668945  predict
# 8  12396.691406  predict
# 9  12398.554688  predict

# %%
fig = px.line(result, x=result.index.values, y="price", color='type', title='Bitcoin Price')
fig.show()
