# %% [markdown]
# # KAN-CDSCO2004U  Machine Learning and Deep Learning
#
# ## Lab 9: Machine Learning and Deep Learning — 📝 Exercise
# **Estimated time: 1 hour**
#
# ### Learning Objectives
# By the end of this exercise, you will be able to:
# - Run the **Perceptron** algorithm on the Iris dataset
# - Apply an **MLP Classifier** Neural Network
# - Clean, scale, and split datasets for classification
#
# **How to work through this notebook:**
# - 🏃 **RUN** cells = Just execute the code to see the output
# - ✏️ **TODO** cells = Write your own code or answer questions
# - 📖 **READ** cells = Explanations to help you understand the concepts

# %% [markdown]
# ✏️ **TODO**
#
# # Exercise-01 Use Perceptron on Irisdataset.
# - Run Perceptron on Iris dataset (use petal length, petal width festures only)

# %%
# Common imports
import numpy as np
import pandas as pd
import os
import matplotlib
import matplotlib.pyplot as plt

from sklearn import metrics
from sklearn.datasets import load_iris
# Perceptron import
from sklearn.linear_model import Perceptron
from matplotlib.colors import ListedColormap
from sklearn.neural_network import MLPClassifier # neural network
from sklearn.preprocessing import MinMaxScaler

# %%
# Load the dataset
iris = load_iris()
# Store in X and y as usual
X = iris.data[:, (2, 3)]  # petal length, petal width
y = (iris.target == 0).astype(int)

# %%
# Step 1: Initialize and train the Perceptron model.
# - We set max_iter=100 and random_state=42 explicitly to avoid warnings
#   about default parameter values.

# Step 2: Make a prediction using the trained model.
# - Predict the class for a new sample with e.g. petal length=2 and petal width=0.5

# Step 3: Compute the decision boundary parameters.
# - Calculate 'a' (slope) and 'b' (intercept) for the decision boundary line.
# - These come from the model's coefficients and intercept.

# Step 4: Define the axes limits for visualization.

# Step 5: Create a meshgrid over the feature space.
# - This grid is used to predict and visualize decision regions.

# Step 6: Combine the grid into coordinate pairs.
# - np.c_ concatenates the two arrays into a single 2D array.

# Step 7: Predict the class for every point in the grid.

# Step 8: Reshape the prediction results to match the meshgrid's shape.
# - This step is necessary for plotting the decision regions with contourf.

# #[Idea]: Go back to the slides and try to fully understand the perceptron. Then, the steps are easier to follow.
# - Experiment with different parameters (like max_iter) to see their impact.

# %%
# Step 1: Create a new figure
# - Set the figure size to (10, 4) inches.

# Step 2: Plot the data points
# - Plot points for the class "Not Iris-Setosa" (where y == 0) using blue squares.
# - Plot points for the class "Iris-Setosa" (where y == 1) using yellow circles.

# Step 3: Plot the decision boundary line
# - Use the slope 'a' and intercept 'b' to calculate the line over the x-range defined in 'axes'.

# Step 4: Create a custom colormap for the decision regions
# - This colormap will be used to visually differentiate areas classified as different classes.

# Step 5: Set global plot appearance parameters
# - Adjust label and tick sizes to ensure the plot is readable.

# Step 6: Plot the decision regions
# - Use contourf to fill the background of the plot with colors from our custom colormap.
# - 'x0' and 'x1' form the grid, and 'zz' holds the predicted class for each grid point.

# Step 7: Add axis labels and legend
# - Label the x-axis as "Petal length" and the y-axis as "Petal width".
# - Display the legend at the lower right of the plot.

# Step 8: Set the axis limits
# - The 'axes' list defines the [xmin, xmax, ymin, ymax] for the plot.

# Step 9: Display the final plot

# [Idea]: Consider storing these plotting commands in a cheat-sheet notebook for easy reuse.
# [Idea]: Explain the plotted diagram in your own words to fully understand how the decision boundary
# and classification regions relate to the data points.

# %% [markdown]
# ✏️ **TODO**
#
# ## Now apply MLP on the above data
# - Now, we want to use all 4 features as X and three classes as y.
# - Use a MLP Neural Network with 50 hidden layers

# %%
# TODO: Write your code here

# %%
# TODO: Write your code here

# %%
# TODO: Write your code here

# %%
# TODO: Write your code here

# %%
# TODO: Write your code here

# %%
# TODO: Write your code here

# %%
# TODO: Write your code here

# %%
# TODO: Write your code here

# %%
# TODO: Write your code here

# %%
# TODO: Write your code here

# %% [markdown]
# 🏃 **RUN**
#
# # Exercise-02. Visualization of MLP weights on MNIST dataset
# - Use MLP for the the MNIST dataset to visualize the MLP weights. use MLPClassifier from scikit library to do that.
# - Call SGD solver

# %%
#import the packages
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml
from sklearn.neural_network import MLPClassifier

# %%
# Load data from https://www.openml.org/d/554; 
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.fetch_openml.html
X, y = fetch_openml('mnist_784', version=1, return_X_y=True) #returns (data, target) instead of a Bunch object
X = X / 255.

# %%
# TODO: Write your code here

# %%
# TODO: Write your code here

# %%
# TODO: Write your code here
